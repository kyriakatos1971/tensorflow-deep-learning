# %% [markdown]
# <a href="https://colab.research.google.com/github/kyriakatos1971/tensorflow-deep-learning/blob/main/01_neural_network_regression_with_tensorflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to Regression with Neural Networks in Tensorflow

# %%
# Import Tensorflow
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.9.2

# %%
# Creating some data for view and fit
import numpy as np
import matplotlib.pyplot as plt

# Create features

X = np.array([-7.0,-4.0,-1.0,2.0,5.0,8.0,11.0,13.0])

# Create labels 

y = np.array([3.0,6.0,9.0,12.0,15.0,18.0,21.0,23.0])


# Visualize it
plt.scatter(X,y);

# %%
#Create a demo tensor for housing price prediction problem

house_info = tf.constant(["bedroom","bathroom","garage"])
house_price = tf.constant([939700])

house_info, house_price
# Out:
# (<tf.Tensor: shape=(3,), dtype=string, numpy=array([b'bedroom', b'bathroom', b'garage'], dtype=object)>,
#  <tf.Tensor: shape=(1,), dtype=int32, numpy=array([939700], dtype=int32)>)

# %%
input_shape = X.shape
output_shape = y.shape

input_shape, output_shape
# Out:
# ((8,), (8,))

# %% [markdown]
# ## Steps in modelling with Tensorflow
#
# 1. **Creating a model** - define the input and the output layers, as well as the hidden layers of a deep learning moddel.
# 2. **Compiling a model** - define the loss functions and the optimizer and evaluation metrics
# 3. **Fitting a model**

# %%
# Set random seed
tf.random.set_seed(42)


# 1. Create a model using the Sequential API
model = tf.keras.Sequential([tf.keras.layers.Dense(1)])

# 2. Compitle the model
model.compile(loss=tf.keras.losses.mae, optimizer = tf.keras.optimizers.SGD(), metrics = ["mae"])

# 3. Fit the model

model.fit(tf.expand_dims(X, axis=-1),y, epochs=1400)
# Out:
# Epoch 1/1400
# 1/1 [==============================] - 1s 610ms/step - loss: 11.4510 - mae: 11.4510
# Epoch 2/1400
# 1/1 [==============================] - 0s 8ms/step - loss: 11.3271 - mae: 11.3271
# Epoch 3/1400
# 1/1 [==============================] - 0s 10ms/step - loss: 11.2032 - mae: 11.2032
# Epoch 4/1400
# 1/1 [==============================] - 0s 18ms/step - loss: 11.0793 - mae: 11.0793
# Epoch 5/1400
# 1/1 [==============================] - 0s 8ms/step - loss: 10.9554 - mae: 10.9554
# Epoch 6/1400
# 1/1 [==============================] - 0s 8ms/step - loss: 10.8315 - mae: 10.8315
# Epoch 7/1400
# 1/1 [==============================] - 0s 8ms/step - loss: 10.7076 - mae: 10.7076
# Epoch 8/1400
# 1/1 [==============================] - 0s 7ms/step - loss: 10.5837 - mae: 10.5837
# Epoch 9/1400
# 1/1 [==============================] - 0s 7ms/step - loss: 10.4598 - mae: 10.4598
# Epoch 10/1400
# 1/1 [==============================] - 0s 8ms/step - loss: 10.3359 - mae: 10.3359
# ...

# %%
# Check out X and y

X, y
# Out:
# (array([-7., -4., -1.,  2.,  5.,  8., 11., 13.]),
#  array([ 3.,  6.,  9., 12., 15., 18., 21., 23.]))

# %%
# Try and make a prediction

model.predict([17.0])
# Out:
# 1/1 [==============================] - 0s 94ms/step
# array([[27.304111]], dtype=float32)

# %% [markdown]
# # Improving our model

# %% [markdown]
# 1. **Creating a model** -  add more layers, incr. number of hiddedn units, change the activation function of each layer
# 2. **Compiling a model** - change the optimization function or its learning rate
# 3. **Fitting a model** - fit a model for more **epochs** or on more data

# %%
# Let's rebuild our model

# 1. Create a model (specified to your problem)
model = tf.keras.Sequential([
  tf.keras.layers.Dense(100, activation="relu"),
  tf.keras.layers.Dense(100, activation="relu"),
  tf.keras.layers.Dense(100, activation="relu"),
  tf.keras.layers.Dense(1)])

# 2. Compile the model
model.compile(loss=tf.keras.losses.mae, optimizer = tf.keras.optimizers.SGD(), metrics = ["mae"])

# 3. Fit the model

model.fit(tf.expand_dims(X, axis=-1),y, epochs=100)


model.predict([17.0])
# Out:
# Epoch 1/100
# 1/1 [==============================] - 1s 509ms/step - loss: 14.1684 - mae: 14.1684
# Epoch 2/100
# 1/1 [==============================] - 0s 15ms/step - loss: 13.7480 - mae: 13.7480
# Epoch 3/100
# 1/1 [==============================] - 0s 10ms/step - loss: 13.3548 - mae: 13.3548
# Epoch 4/100
# 1/1 [==============================] - 0s 11ms/step - loss: 12.9911 - mae: 12.9911
# Epoch 5/100
# 1/1 [==============================] - 0s 9ms/step - loss: 12.6427 - mae: 12.6427
# Epoch 6/100
# 1/1 [==============================] - 0s 9ms/step - loss: 12.2850 - mae: 12.2850
# Epoch 7/100
# 1/1 [==============================] - 0s 14ms/step - loss: 11.9162 - mae: 11.9162
# Epoch 8/100
# 1/1 [==============================] - 0s 15ms/step - loss: 11.5069 - mae: 11.5069
# Epoch 9/100
# 1/1 [==============================] - 0s 9ms/step - loss: 11.0533 - mae: 11.0533
# Epoch 10/100
# 1/1 [==============================] - 0s 8ms/step - loss: 10.4990 - mae: 10.4990
# ...

# %%
# Let's rebuild our model - Take 2

# 1. Create a model (specified to your problem)
model = tf.keras.Sequential([
  tf.keras.layers.Dense(100, activation="relu"),
  tf.keras.layers.Dense(100, activation="relu"),
  tf.keras.layers.Dense(100, activation="relu"),
  tf.keras.layers.Dense(1)])

# 2. Compile the model
model.compile(loss=tf.keras.losses.mae, optimizer = tf.keras.optimizers.SGD(), metrics = ["mae"])

# 3. Fit the model

model.fit(tf.expand_dims(X, axis=-1),y, epochs=500)


# Try and make a prediction

model.predict([17.0])
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 454ms/step - loss: 12.9025 - mae: 12.9025
# Epoch 2/500
# 1/1 [==============================] - 0s 13ms/step - loss: 12.3436 - mae: 12.3436
# Epoch 3/500
# 1/1 [==============================] - 0s 12ms/step - loss: 11.7193 - mae: 11.7193
# Epoch 4/500
# 1/1 [==============================] - 0s 11ms/step - loss: 11.0767 - mae: 11.0767
# Epoch 5/500
# 1/1 [==============================] - 0s 11ms/step - loss: 10.3426 - mae: 10.3426
# Epoch 6/500
# 1/1 [==============================] - 0s 12ms/step - loss: 9.4390 - mae: 9.4390
# Epoch 7/500
# 1/1 [==============================] - 0s 7ms/step - loss: 8.3192 - mae: 8.3192
# Epoch 8/500
# 1/1 [==============================] - 0s 9ms/step - loss: 6.8921 - mae: 6.8921
# Epoch 9/500
# 1/1 [==============================] - 0s 15ms/step - loss: 5.1969 - mae: 5.1969
# Epoch 10/500
# 1/1 [==============================] - 0s 12ms/step - loss: 3.9002 - mae: 3.9002
# Epoch 11/500
# ...

# %%
# Let's rebuild our model - Take 3

# 1. Create a model (specified to your problem)
model = tf.keras.Sequential([
  tf.keras.layers.Dense(100, activation="relu"),
  tf.keras.layers.Dense(100, activation="relu"),
  tf.keras.layers.Dense(100, activation="relu"),
  tf.keras.layers.Dense(1)])

# 2. Compile the model
model.compile(loss=tf.keras.losses.mae, optimizer = tf.keras.optimizers.Adam(lr=0.001), metrics = ["mae"])

# 3. Fit the model

model.fit(tf.expand_dims(X, axis=-1),y, epochs=500)


# Try and make a prediction

model.predict([17.0])
# Out:
# Epoch 1/500
# /usr/local/lib/python3.7/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 1/1 [==============================] - 1s 859ms/step - loss: 13.6381 - mae: 13.6381
# Epoch 2/500
# 1/1 [==============================] - 0s 13ms/step - loss: 13.2858 - mae: 13.2858
# Epoch 3/500
# 1/1 [==============================] - 0s 13ms/step - loss: 12.9687 - mae: 12.9687
# Epoch 4/500
# 1/1 [==============================] - 0s 11ms/step - loss: 12.6793 - mae: 12.6793
# Epoch 5/500
# 1/1 [==============================] - 0s 15ms/step - loss: 12.3947 - mae: 12.3947
# Epoch 6/500
# 1/1 [==============================] - 0s 10ms/step - loss: 12.1173 - mae: 12.1173
# Epoch 7/500
# 1/1 [==============================] - 0s 10ms/step - loss: 11.8373 - mae: 11.8373
# Epoch 8/500
# 1/1 [==============================] - 0s 11ms/step - loss: 11.5490 - mae: 11.5490
# ...

# %% [markdown]
# ## Evaluating a model
#
# Where it comes to evaluation there are 3 key words:
# "visualize, visualize, visualize"
#
# * The data
# * The model itself
# * The training of a model
# * The predictions of a model

# %%
# Make a bigger data set
X = tf.range(-100, 100, 4)
X
# Out:
# <tf.Tensor: shape=(50,), dtype=int32, numpy=
# array([-100,  -96,  -92,  -88,  -84,  -80,  -76,  -72,  -68,  -64,  -60,
#         -56,  -52,  -48,  -44,  -40,  -36,  -32,  -28,  -24,  -20,  -16,
#         -12,   -8,   -4,    0,    4,    8,   12,   16,   20,   24,   28,
#          32,   36,   40,   44,   48,   52,   56,   60,   64,   68,   72,
#          76,   80,   84,   88,   92,   96], dtype=int32)>

# %%
# Make labels for the dataset
y = X + 10
y
# Out:
# <tf.Tensor: shape=(50,), dtype=int32, numpy=
# array([-90, -86, -82, -78, -74, -70, -66, -62, -58, -54, -50, -46, -42,
#        -38, -34, -30, -26, -22, -18, -14, -10,  -6,  -2,   2,   6,  10,
#         14,  18,  22,  26,  30,  34,  38,  42,  46,  50,  54,  58,  62,
#         66,  70,  74,  78,  82,  86,  90,  94,  98, 102, 106], dtype=int32)>

# %%
# Visualize the data
import matplotlib.pyplot as plt

plt.scatter(X,y)

# %%
### The three sets...

# %% [markdown]
# ### The three sets ...
#
# * Training set  : 70-80%
# * Validation Set : 10-15%
# * Test Set : 10-15%

# %%
# Check the length of how many samples we have
len(X)
# Out:
# 50

# %%
# Split the data into train and test sets
X_train = X[:40] #first 40 are training samples
y_train = y[:40]

X_test = X[40:] #last 10 are testing samples
y_test = y[40:]


len(X_train), len(y_train), len(X_test), len(y_test)
# Out:
# (40, 40, 10, 10)

# %%
#### Visualizing the data

plt.figure(figsize=(10,7))
#Plot training data in green
plt.scatter(X_train, y_train, c="g", label="Trainingdata")
#Plot testing data in red
plt.scatter(X_test, y_test, c="r", label="Testing data")
# SHow a legend
plt.legend()

# %%
# Build a neural network for our data

# 1. Create a model using the Sequential API
model = tf.keras.Sequential([tf.keras.layers.Dense(3)])

# 2. Compitle the model
model.compile(loss=tf.keras.losses.mae, optimizer = tf.keras.optimizers.SGD(), metrics = ["mae"])

# 3. Fit the model

model.fit(tf.expand_dims(X_train, axis=-1),y_train, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 0s 7ms/step - loss: 46.3793 - mae: 46.3793
# Epoch 2/100
# 2/2 [==============================] - 0s 6ms/step - loss: 34.9062 - mae: 34.9062
# Epoch 3/100
# 2/2 [==============================] - 0s 8ms/step - loss: 24.1982 - mae: 24.1982
# Epoch 4/100
# 2/2 [==============================] - 0s 6ms/step - loss: 16.3971 - mae: 16.3971
# Epoch 5/100
# 2/2 [==============================] - 0s 8ms/step - loss: 10.1295 - mae: 10.1295
# Epoch 6/100
# 2/2 [==============================] - 0s 5ms/step - loss: 7.8268 - mae: 7.8268
# Epoch 7/100
# 2/2 [==============================] - 0s 6ms/step - loss: 8.2673 - mae: 8.2673
# Epoch 8/100
# 2/2 [==============================] - 0s 7ms/step - loss: 7.7882 - mae: 7.7882
# Epoch 9/100
# 2/2 [==============================] - 0s 7ms/step - loss: 8.7773 - mae: 8.7773
# Epoch 10/100
# 2/2 [==============================] - 0s 5ms/step - loss: 8.6037 - mae: 8.6037
# Epoch 11/100
# ...

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_15 (Dense)            (None, 3)                 6
#
# ...
# Total params: 6
# Trainable params: 6
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model

plot_model(model=model, show_shapes=True)

# %% [markdown]
# ### Visualizing our model's predictions

# %%
# Make some predictions

y_pred = model.predict(X_test)
y_pred
# Out:
# 1/1 [==============================] - 0s 19ms/step
# array([[56.708424, 57.50081 , 57.56255 ],
#        [60.45746 , 61.303432, 61.369442],
#        [64.2065  , 65.10606 , 65.17633 ],
#        [67.95553 , 68.908676, 68.98322 ],
#        [71.70456 , 72.7113  , 72.790115],
#        [75.4536  , 76.51392 , 76.59701 ],
#        [79.20263 , 80.31655 , 80.4039  ],
#        [82.95166 , 84.11917 , 84.21079 ],
#        [86.7007  , 87.9218  , 88.017685],
#        [90.44973 , 91.72442 , 91.82458 ]], dtype=float32)

# %%
# Let's create a plotting function

def plot_predictions(train_data=X_train, train_labels=y_train, 
                     test_data=X_test, test_labels=y_test, predictions=y_pred):
  
  """
  Plots training data, test data and compares predictions to ground truth labels.
  """

  plt.figure(figsize = (10,7))

  # Plot training data in green
  plt.scatter(train_data,train_labels,c="g",label="Training Data")
  
  # Plot testing data in red
  plt.scatter(test_data, test_labels,c="r",label="Testing Data")

  # Plot predictions in blue
  plt.scatter(test_data, predictions, c="b", label="Predictions")

  # Show the legend
  plt.legend();


plot_predictions()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-12e9f8a9b70e> in <module>
#      23
#      24
# ---> 25 plot_predictions()
#
# <ipython-input-35-12e9f8a9b70e> in plot_predictions(train_data, train_labels, test_data, test_labels, predictions)
#      17
#      18   # Plot predictions in blue
# ---> 19   plt.scatter(test_data, predictions, c="b", label="Predictions")
#      20
#      21   # Show the legend
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2814         verts=verts, edgecolors=edgecolors,
#    2815         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2816         None else {}), **kwargs)
#    2817     sci(__ret)
#    2818     return __ret
#
# ...

# %%
y_test
# Out:
# <tf.Tensor: shape=(10,), dtype=int32, numpy=array([ 70,  74,  78,  82,  86,  90,  94,  98, 102, 106], dtype=int32)>

# %%
y_pred
# Out:
# array([[56.708424, 57.50081 , 57.56255 ],
#        [60.45746 , 61.303432, 61.369442],
#        [64.2065  , 65.10606 , 65.17633 ],
#        [67.95553 , 68.908676, 68.98322 ],
#        [71.70456 , 72.7113  , 72.790115],
#        [75.4536  , 76.51392 , 76.59701 ],
#        [79.20263 , 80.31655 , 80.4039  ],
#        [82.95166 , 84.11917 , 84.21079 ],
#        [86.7007  , 87.9218  , 88.017685],
#        [90.44973 , 91.72442 , 91.82458 ]], dtype=float32)

# %%
loss= tf.keras.losses.mean_absolute_error(y_train,y_pred)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-40-ab30229f49fd> in <module>
# ----> 1 loss= tf.keras.losses.mean_absolute_error(y_train,y_pred)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
#     155       del filtered_tb
#
# /usr/local/lib/python3.7/dist-packages/keras/losses.py in mean_absolute_error(y_true, y_pred)
#    1453   y_pred = tf.convert_to_tensor(y_pred)
#    1454   y_true = tf.cast(y_true, y_pred.dtype)
# -> 1455   return backend.mean(tf.abs(y_pred - y_true), axis=-1)
#    1456
#    1457
#
# InvalidArgumentError: Incompatible shapes: [10,3] vs. [40] [Op:Sub]
